# %% [markdown]
# #### [G Henry Jacob](https://in.linkedin.com/in/henry-jacob-96872918a)

# %% [markdown]
# <p>22<sup>nd</sup> sep 2021</p>

# %% [markdown]
# <!DOCTYPE html>
# <head>
# <style>
#
#
# </style>
# </head>
# <body>
# This is the <a href = 'https://drive.google.com/drive/folders/11ljnOA3VJTr6nHUegp3CsR6MbjMGnciv'> first assignment</a> given by <a = href = 'https://www.guvi.in/'> Guvi </a> for <b>Batch - D14</b> on 21-09-2021
# </body>

# %% [markdown]
# # Registration and Login system with Python, file handling

# %% [markdown]
# Here I created a function where we can get input(mail_id, password, name for recovery) from user, store them and also check login details. Here I used csv file to store data so, we can store multiple users credentials in same file and it easy to access

# %%
#import packages
import re
import random
import string
import time
import pandas as pd

# define funciton
def reg_log():
    nickname = input('Hi! Please Enter your Nickname :')
    time.sleep(.6)
    name = nickname.capitalize()
    greets = ['Hi!', 'Hello!', 'Hey!', 'Hai!']
    time.sleep(.6)
    print(random.choice(greets), name,' Could you please choose anyone from below')
    time.sleep(.4)
    mode = input('Register/Login :')
    mode = mode.lower()
    reg_modes = ['register', 'reg', 'r', '1']
    login_modes = ['login', 'log', 'l', '2']
    time.sleep(.6)
    # if condtition for registration
    if mode in reg_modes:
        # try block for try to get csv file if already file exists
        try:
            df1 = pd.read_csv('user.csv')
            print(name, " Thanks to become one of our user, Let's begin your journey from here")
            time.sleep(.6)
            mail = input('Please enter valid email address (Example :"sherlock@gmail.com", "nothing@yahoo.in"):')
            alice = []
            dot = []
            re_alice = re.finditer(r"@", mail)
            for i in re_alice:
                alice.append(i.start())
            for i in range(len(mail)):
                if mail[i] == '.':
                    dot.append(i)
            # make sure there must be one "@" and one "."
            if (len(alice) < 2) & (len(dot) < 2):
                # condition1 email/username should have "@" and followed by "."
                if alice[0] < dot[0]:
                    alpha_lower = [x for x in string.ascii_lowercase]
                    # condition2 it should not be like this eg:- @gmail.com
                    if mail[0].lower() in alpha_lower:
                        # condition3 there should not be any "." immediate next to "@" my@.in
                        if dot[0] - alice[0]  != 1:
                            time.sleep(.6)
                            print('Hooray! You entered a valid email id\nFew steps to go...')
                            time.sleep(.6)
                            print('Please provide a password which Must have \n1.Password length should be 5 - 16.\n2.minimum one special character,\n3.one digit, \n4.one uppercase,\n5.one lowercase character')
                            password = input('Please enter password :')
                            # condition4 password (5 < password length > 16)
                            if (len(password) > 4) & (len(password) < 17):
                                special_char = '[@_!#$%^&*()<>?/\|}{~:]'
                                digit_str = [str(x) for x in range(10)]
                                alpha_upper = [x for x in string.ascii_uppercase]

                                special_char_count = 0
                                digit_count = 0
                                alpha_upper_count = 0
                                alpha_lower_count = 0
                                for i in password:
                                    if i in special_char:
                                        special_char_count += 1
                                    elif i in digit_str:
                                        digit_count += 1
                                    elif i in alpha_upper:
                                        alpha_upper_count += 1
                                    else:
                                        if i in alpha_lower:
                                            alpha_lower_count += 1
                                if (special_char_count > 0) & (digit_count > 0) & (alpha_upper_count > 0) & (alpha_lower_count > 0):
                                    df2 = pd.DataFrame({'name':[name],'mail_id':[mail], 'password':[password]})
                                    df1 = df1.append(df2, ignore_index= True)
                                    df1.to_csv('user.csv', index=False)
                                    print('Your credential is accepted')

                                else:
                                    time.sleep(.6)
                                    print('Password does not satisfy above condition')

                            else:
                                if len(password) < 5:
                                    time.sleep(.6)
                                    print('Password length too short')
                                    time.sleep(.6)
                                    print('Kindly refresh the page and give your credential once again')
                                else:
                                    time.sleep(.6)
                                    print('Password length too long')
                                    time.sleep(.6)
                                    print('Kindly refresh the page and give your credential once again')

                        else:
                            time.sleep(.6)
                            print('there should not be any "." immediate next to "@"')
                            time.sleep(.6)
                            print('Kindly refresh the page and give your credential once again')

                    else:
                        time.sleep(.6)
                        print('First letter must be a character')
                        time.sleep(.6)
                        print('Kindly refresh the page and give your credential once again')
                else:
                    time.sleep(.6)
                    print('email/username should have "@" and followed by "."')
                    time.sleep(.6)
                    print('Kindly refresh the page and give your credential once again')

            else:
                time.sleep(.6)
                print('There must be one "@" and one "." can present')
                time.sleep(.6)
                print('Kindly refresh the page and give your credential once again')
        
        # exception for create new data and store when try block failed
        except FileNotFoundError:

            print(name, " Thanks to become one of our user, Let's begin your journey from here")
            time.sleep(.6)
            mail = input('Please enter valid email address (Example :"sherlock@gmail.com", "nothing@yahoo.in"):')
            alice = []
            dot = []
            re_alice = re.finditer(r"@", mail)
            for i in re_alice:
                alice.append(i.start())
            for i in range(len(mail)):
                if mail[i] == '.':
                    dot.append(i)
            # make sure there must be one "@" and one "."
            if (len(alice) < 2) & (len(dot) < 2):
                # condition1 email/username should have "@" and followed by "."
                if alice[0] < dot[0]:
                    alpha_lower = [x for x in string.ascii_lowercase]
                    # condition2 it should not be like this eg:- @gmail.com
                    if mail[0].lower() in alpha_lower:
                        # condition3 there should not be any "." immediate next to "@" my@.in
                        if dot[0] - alice[0]  != 1:
                            time.sleep(.6)
                            print('Hooray! You entered a valid email id\nFew steps to go...')
                            time.sleep(.6)
                            print('Please provide a password which Must have \n1.Password length should be 5 - 16.\n2.minimum one special character,\n3.one digit, \n4.one uppercase,\n5.one lowercase character')
                            password = input('Please enter password :')
                            # condition4 password (5 < password length > 16)
                            if (len(password) > 4) & (len(password) < 17):
                                special_char = '[@_!#$%^&*()<>?/\|}{~:]'
                                digit_str = [str(x) for x in range(10)]
                                alpha_upper = [x for x in string.ascii_uppercase]

                                special_char_count = 0
                                digit_count = 0
                                alpha_upper_count = 0
                                alpha_lower_count = 0
                                for i in password:
                                    if i in special_char:
                                        special_char_count += 1
                                    elif i in digit_str:
                                        digit_count += 1
                                    elif i in alpha_upper:
                                        alpha_upper_count += 1
                                    else:
                                        if i in alpha_lower:
                                            alpha_lower_count += 1
                                if (special_char_count > 0) & (digit_count > 0) & (alpha_upper_count > 0) & (alpha_lower_count > 0):
                                    df = pd.DataFrame({'name':[name],'mail_id':[mail], 'password':[password]})
                                    df.to_csv('user.csv', index=False)
                                    print('Your credential is accepted')

                                else:
                                    time.sleep(.6)
                                    print('Password does not satisfy above condition')

                            else:
                                if len(password) < 5:
                                    time.sleep(.6)
                                    print('Password length too short')
                                    time.sleep(.6)
                                    print('Kindly refresh the page and give your credential once again')
                                else:
                                    time.sleep(.6)
                                    print('Password length too long')
                                    time.sleep(.6)
                                    print('Kindly refresh the page and give your credential once again')

                        else:
                            time.sleep(.6)
                            print('there should not be any "." immediate next to "@"')
                            time.sleep(.6)
                            print('Kindly refresh the page and give your credential once again')

                    else:
                        time.sleep(.6)
                        print('First letter must be a character')
                        time.sleep(.6)
                        print('Kindly refresh the page and give your credential once again')
                else:
                    time.sleep(.6)
                    print('email/username should have "@" and followed by "."')
                    time.sleep(.6)
                    print('Kindly refresh the page and give your credential once again')

            else:
                time.sleep(.6)
                print('There must be one "@" and one "." can present')
                time.sleep(.6)
                print('Kindly refresh the page and give your credential once again')
    
    # elif condition to check if it is a login
    elif mode in login_modes:
        # try block for check is there any file exist
        try:
            df = pd.read_csv('user.csv')
            time.sleep(.6)
            print("Hey! Happy to see you again...")
            time.sleep(.6)
            mail_1 = input('Please enter your email address :')
            time.sleep(.6)
            password_1 = input('Please enter your password :')
            list_user = list(df['mail_id'])
            if mail_1 in list_user:
                list_password = list(df['password'])
                for i in range(len(list_user)):
                    if list_user[i] == mail_1:
                        if list_password[i] == password_1:
                            print('Yes! your credential exists')

                        else:
                            time.sleep(.6)
                            print('Hey! It seems you forget your password')
                            time.sleep(.6)
                            rec_option = input('Do you want to recover it ?')
                            pos = ['1', 'yes', 'y', 'Yes', 'Y', 'yep', 'Yep', 'yup', 'Yup', 'yeah', 'Yeah']
                            if rec_option in pos:
                                rec = input('Please provide your nickname for password recovery :')
                                if rec.capitalize() == list(df['name'])[i]:
                                    loading = ['.' for i in range(10)]
                                    time.sleep(.6)
                                    print('processing ', end="")
                                    for j in range(len(loading) - 1):
                                        print(loading[j], end = "")
                                        time.sleep(.4)
                                    print('.')
                                    time.sleep(.3)
                                    print('password is :',list(df['password'])[i])
                                else:
                                    loading = ['.' for j in range(10)]
                                    print('processing ', end="")
                                    for j in range(len(loading) - 1):
                                        print(loading[j], end = "")
                                        time.sleep(.3)
                                    print('.')
                                    time.sleep(.3)
                                    print('Name mismatch')
                                    print('Take your time and come again!')
                            else:
                                print('Try to remember your password and come again.')
           
            else:
                time.sleep(.5)
                print('Hello! We noticed that you are not a old user kindley register')
        # exception block when try block failed       
        except FileNotFoundError:
            time.sleep(.6)
            print('There is no data present')
            time.sleep(.6)
            print('You have to give your credential to store data')
            time.sleep(.6)
            print('Kindly refresh the page and register')
    # else condition when registration and login failed
    else:
        time.sleep(.6)
        print('Unrecognized input')
        time.sleep(.6)
        print('Kindly refresh the page and give your credential once again')
                        
            

reg_log()
